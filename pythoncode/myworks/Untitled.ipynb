# %%
import pandas as pd
import numpy as np
import os
excel_file='값.xlsx'
base_dir_for_ex='C:\Users\i5533\OneDrive\바탕 화면\바탕화면정리\빅데이터공모전\딥러닝\데이터엑셀'
excel_dir=os.path.join(base_dir_for_ex,excel_file)
# Out:
#   File "<ipython-input-1-4abdb31ab325>", line 5
#     base_dir_for_ex='C:\Users\i5533\OneDrive\바탕 화면\바탕화면정리\빅데이터공모전\딥러닝\데이터엑셀'
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import numpy as np
import os
excel_file='값.xlsx'
base_dir_for_ex='C:\\Users\\i5533\\OneDrive\\바탕 화면\\바탕화면정리\\빅데이터공모전\\딥러닝\\데이터엑셀'
excel_dir=os.path.join(base_dir_for_ex,excel_file)

df_from_excel = pd.read_excel(excel_dir,
                              sheet_name = 'Sheet1',
                              header=2,
                              names=['origin','함수1','함수2','버섯이름','현재_존재값','최소','적절'],
                              dtype={'origin': str,
                                     '함수1': str,
                                     '함수2': str,
                                     '버섯이름': str,
                                     '현재_존재값': int,
                                     '최소': int,
                                     '적절': int
                                }
                              )

# %%
df_from_excel
# Out:
#                        origin        함수1  함수2       버섯이름  현재_존재값   최소   적절
# 0          ./train/식용_잎새버섯, 1       잎새버섯    1       잎새버섯       1  199  299
# 1        ./train/식용_뿔나팔버섯, 80      뿔나팔버섯   80      뿔나팔버섯      80  120  220
# 2         ./train/식용_먹물버섯, 44       먹물버섯   44       먹물버섯      44  156  256
# 3     ./train/독버섯_흰알광대버섯, 123     흰알광대버섯  123     흰알광대버섯     123   77  177
# 4   ./train/독버섯_흰오뚜기광대버섯, 138   흰오뚜기광대버섯  138   흰오뚜기광대버섯     138   62  162
# ..                        ...        ...  ...        ...     ...  ...  ...
# 58         ./train/식용_젖버섯, 27        젖버섯   27        젖버섯      27  173  273
# 59      ./train/독버섯_비듬땀버섯, 40      비듬땀버섯   40      비듬땀버섯      40  160  260
# 60       ./train/식용_흰주름버섯, 11      흰주름버섯   11      흰주름버섯      11  189  289
# 61     ./train/독버섯_노란각시버섯, 76     노란각시버섯   76     노란각시버섯      76  124  224
# 62  ./train/독버섯_갈황색미치광이버섯, 94  갈황색미치광이버섯   94  갈황색미치광이버섯      94  106  206
#
# [63 rows x 7 columns]

# %%
df_from_excel['적절']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c69514c969dc> in <module>
# ----> 1 df_from_excel['적절']
#
# NameError: name 'df_from_excel' is not defined

# %%
import pandas as pd
import numpy as np
import os
excel_file='값.xlsx'
base_dir_for_ex='C:\\Users\\i5533\\OneDrive\\바탕 화면\\바탕화면정리\\빅데이터공모전\\딥러닝\\데이터엑셀'
excel_dir=os.path.join(base_dir_for_ex,excel_file)

df_from_excel = pd.read_excel(excel_dir,
                              sheet_name = 'Sheet1',
                              header=2,
                              names=['origin','함수1','함수2','버섯이름','현재_존재값','최소','적절'],
                              dtype={'origin': str,
                                     '함수1': str,
                                     '함수2': str,
                                     '버섯이름': str,
                                     '현재_존재값': int,
                                     '최소': int,
                                     '적절': int
                                }
                              )
df_from_excel['적절']
# Out:
# 0     299
# 1     220
# 2     256
# 3     177
# 4     162
#      ...
# 58    273
# 59    260
# 60    289
# 61    224
# 62    206
# Name: 적절, Length: 63, dtype: int32
